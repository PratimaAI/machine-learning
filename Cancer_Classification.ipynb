# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cancer_classification.csv")

# %% [markdown]
# # Data Analysis

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <AxesSubplot: xlabel='benign_0__mal_1', ylabel='count'>

# %%
corr_matrix= df.corr()['benign_0__mal_1'].sort_values(ascending=False)

# %%
corr_matrix
# Out:
# benign_0__mal_1            1.000000
# smoothness error           0.067016
# mean fractal dimension     0.012838
# texture error              0.008303
# symmetry error             0.006522
# fractal dimension error   -0.077972
# concavity error           -0.253730
# compactness error         -0.292999
# worst fractal dimension   -0.323872
# mean symmetry             -0.330499
# mean smoothness           -0.358560
# concave points error      -0.408042
# mean texture              -0.415185
# worst symmetry            -0.416294
# worst smoothness          -0.421465
# worst texture             -0.456903
# area error                -0.548236
# perimeter error           -0.556141
# radius error              -0.567134
# worst compactness         -0.590998
# mean compactness          -0.596534
# worst concavity           -0.659610
# mean concavity            -0.696360
# mean area                 -0.708984
# mean radius               -0.730029
# worst area                -0.733825
# ...

# %%
corr_matrix.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Train Test split

# %%
X= df.drop('benign_0__mal_1',axis=1)
y= df['benign_0__mal_1']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler= MinMaxScaler()

# %%
X_train= Scaler.fit_transform(X_train)
X_test= Scaler.transform(X_test)

# %% [markdown]
# # Creating the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
y_train.shape
# Out:
# (426,)

# %%
model= Sequential()

model.add(Dense (30, activation= 'relu'))
model.add(Dense (15, activation= 'relu'))

#Binary classificayion problem 

model.add(Dense (1, activation= 'sigmoid'))

model.compile(optimizer= 'adam', loss='binary_crossentropy')

# %%
model.fit(X_train, y_train, epochs=600, validation_data=(X_test, y_test))
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 15ms/step - loss: 0.6993 - val_loss: 0.6832
# Epoch 2/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6604 - val_loss: 0.6510
# Epoch 3/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6230 - val_loss: 0.6114
# Epoch 4/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5834 - val_loss: 0.5743
# Epoch 5/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5470 - val_loss: 0.5377
# Epoch 6/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5138 - val_loss: 0.5058
# Epoch 7/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4835 - val_loss: 0.4756
# Epoch 8/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4554 - val_loss: 0.4460
# Epoch 9/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4273 - val_loss: 0.4163
# Epoch 10/600
# ...

# %%
loss=pd.DataFrame(model.history.history)

# %%
loss
# Out:
#          loss  val_loss
# 0    0.699346  0.683242
# 1    0.660429  0.651017
# 2    0.622988  0.611401
# 3    0.583367  0.574311
# 4    0.547027  0.537706
# ..        ...       ...
# 595  0.017621  0.258225
# 596  0.017023  0.227151
# 597  0.018106  0.228391
# 598  0.017641  0.227005
# 599  0.013157  0.221961
#
# [600 rows x 2 columns]

# %%
loss.plot()
# Out:
# <AxesSubplot: >

# %%
#Because of too many epoch(=600), validation loss is increasing. This is the issue of overfitting.

# %%
# Dropout method and Earlystopping will be used

# %% [markdown]
# # Earlystopping

# %%
model= Sequential()

model.add(Dense (30, activation= 'relu'))
model.add(Dense (15, activation= 'relu'))

#Binary classificayion problem 

model.add(Dense (1, activation= 'sigmoid'))

model.compile(optimizer= 'adam', loss='binary_crossentropy')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop= EarlyStopping(monitor='val_loss', mode= 'min', verbose=1,patience=25)

# %%
model.fit(X_train, y_train, epochs=600, validation_data=(X_test, y_test), callbacks=early_stop)
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 12ms/step - loss: 0.6816 - val_loss: 0.6655
# Epoch 2/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6462 - val_loss: 0.6312
# Epoch 3/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6112 - val_loss: 0.5951
# Epoch 4/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5719 - val_loss: 0.5517
# Epoch 5/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5269 - val_loss: 0.5024
# Epoch 6/600
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4798 - val_loss: 0.4526
# Epoch 7/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4345 - val_loss: 0.4066
# Epoch 8/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3869 - val_loss: 0.3593
# Epoch 9/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3472 - val_loss: 0.3177
# Epoch 10/600
# ...

# %%
model_loss=pd.DataFrame(model.history.history)

# %%
model_loss
# Out:
#         loss  val_loss
# 0   0.681640  0.665461
# 1   0.646192  0.631226
# 2   0.611245  0.595114
# 3   0.571934  0.551726
# 4   0.526907  0.502415
# ..       ...       ...
# 61  0.057021  0.114384
# 62  0.057868  0.119189
# 63  0.058488  0.108846
# 64  0.058946  0.114133
# 65  0.072643  0.111727
#
# [66 rows x 2 columns]

# %%
model_loss.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Dropout

# %%
model= Sequential()

model.add(Dense (30, activation= 'relu'))
model.add(Dropout (0.5))

model.add(Dense (15, activation= 'relu'))
model.add(Dropout (0.5))

#Binary classificayion problem 

model.add(Dense (1, activation= 'sigmoid'))

model.compile(optimizer= 'adam', loss='binary_crossentropy')

# %%
model.fit(X_train, y_train, epochs=600, validation_data=(X_test, y_test), callbacks=early_stop)
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 12ms/step - loss: 0.7358 - val_loss: 0.6730
# Epoch 2/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6760 - val_loss: 0.6399
# Epoch 3/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6605 - val_loss: 0.6093
# Epoch 4/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6467 - val_loss: 0.5797
# Epoch 5/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6250 - val_loss: 0.5493
# Epoch 6/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5719 - val_loss: 0.5183
# Epoch 7/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5537 - val_loss: 0.4834
# Epoch 8/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5289 - val_loss: 0.4504
# Epoch 9/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4988 - val_loss: 0.4190
# Epoch 10/600
# ...

# %%
model_loss=pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot: >

# %%
predictions= model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
predictions = (predictions > 0.5).astype(int)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        55
#            1       0.99      0.98      0.98        88
#
#     accuracy                           0.98       143
#    macro avg       0.98      0.98      0.98       143
# weighted avg       0.98      0.98      0.98       143

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[54  1]
#  [ 2 86]]
